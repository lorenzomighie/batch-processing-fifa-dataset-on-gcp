# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('fifa-transformation') \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/13 10:18:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.option("basePath", "dataset/").parquet('dataset/*/*')
df.columns
# Out:
# ['sofifa_id',
#  'short_name',
#  'overall',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality_name',
#  'club_name',
#  'league_name',
#  'league_level',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'gender',
#  'unique_id',
#  'version']

# %%
print((df.count(), len(df.columns)))
df.show()
# Out:
# (144323, 18)
# +---------+-------------+-------+---+-------------------+---------+---------+----------------+---------+-----------+------------+---------+---------+--------+----------------+------+-----------+-------+
# |sofifa_id|   short_name|overall|age|                dob|height_cm|weight_kg|nationality_name|club_name|league_name|league_level|potential|value_eur|wage_eur|player_positions|gender|  unique_id|version|
# +---------+-------------+-------+---+-------------------+---------+---------+----------------+---------+-----------+------------+---------+---------+--------+----------------+------+-----------+-------+
# |   227246|    L. Bronze|     92| 29|1991-10-28 00:00:00|      171|       67|         England|  unknown|       null|        null|       92|     null|    null|          RB, CM|female|25769820906|     22|
# |   227316|    W. Renard|     92| 30|1990-07-20 00:00:00|      187|       70|          France|  unknown|       null|        null|       92|     null|    null|              CB|female|25769820907|     22|
# |   233746|   V. Miedema|     92| 24|1996-07-15 00:00:00|      178|       65|     Netherlands|  unknown|       null|        null|       93|     null|    null|              ST|female|25769820908|     22|
# |   227125|      S. Kerr|     91| 27|1993-09-10 00:00:00|      167|       55|       Australia|  unknown|       null|        null|       91|     null|    null|          ST, LW|female|25769820909|     22|
# |   226301|    A. Morgan|     90| 31|1989-07-02 00:00:00|      170|       62|   United States|  unknown|       null|        null|       90|     null|    null|              ST|female|25769820910|     22|
# |   226308|  D. Marozsán|     90| 29|1992-04-18 00:00:00|      171|       67|         Germany|  unknown|       null|        null|       90|     null|    null|     CAM, LM, CM|female|25769820911|     22|
# |   226328|   M. Rapinoe|     90| 35|1985-07-05 00:00:00|      170|       60|   United States|  unknown|       null|        null|       90|     null|    null|          LW, LM|female|25769820912|     22|
# |   226330|     T. Heath|     90| 33|1988-05-29 00:00:00|      168|       59|   United States|  unknown|       null|        null|       90|     null|    null|     RW, CAM, LW|female|25769820913|     22|
# |   227102|    C. Hansen|     90| 26|1995-02-18 00:00:00|      178|       66|          Norway|  unknown|       null|        null|       91|     null|    null|     RM, CAM, ST|female|25769820914|     22|
# |   227318|     A. Henry|     90| 31|1989-09-28 00:00:00|      171|       64|          France|  unknown|       null|        null|       90|     null|    null|         CDM, CM|female|25769820915|     22|
# |   226333|      J. Ertz|     89| 29|1992-04-06 00:00:00|      170|       59|   United States|  unknown|       null|        null|       89|     null|    null|         CDM, CB|female|25769820916|     22|
# |   226359|  C. Sinclair|     89| 38|1983-06-12 00:00:00|      175|       67|          Canada|  unknown|       null|        null|       89|     null|    null|         ST, CAM|female|25769820917|     22|
# |   227331| E. Le Sommer|     89| 32|1989-05-18 00:00:00|      161|       58|          France|  unknown|       null|        null|       89|     null|    null|     ST, LW, CAM|female|25769820918|     22|
# |   233748|   L. Martens|     89| 28|1992-12-16 00:00:00|      170|       66|     Netherlands|  unknown|       null|        null|       89|     null|    null|         LW, CAM|female|25769820919|     22|
# |   226177|B. Sauerbrunn|     88| 36|1985-06-06 00:00:00|      170|       64|   United States|  unknown|       null|        null|       88|     null|    null|          CB, RB|female|25769820920|     22|
# |   226302|      A. Popp|     88| 30|1991-04-06 00:00:00|      174|       65|         Germany|  unknown|       null|        null|       88|     null|    null|          ST, LM|female|25769820921|     22|
# |   227255|     F. Kirby|     88| 28|1993-06-29 00:00:00|      157|       53|         England|  unknown|       null|        null|       88|     null|    null|     CAM, ST, CM|female|25769820922|     22|
# |   227192|Jenni Hermoso|     87| 31|1990-05-09 00:00:00|      174|       59|           Spain|  unknown|       null|        null|       87|     null|    null|     ST, CAM, CF|female|25769820923|     22|
# |   227327|   S. Däbritz|     87| 26|1995-02-15 00:00:00|      171|       59|         Germany|  unknown|       null|        null|       89|     null|    null|     CM, LM, CAM|female|25769820924|     22|
# |   227350|     A. Majri|     87| 28|1993-01-25 00:00:00|      164|       54|          France|  unknown|       null|        null|       87|     null|    null|          LM, LB|female|25769820925|     22|
# +---------+-------------+-------+---+-------------------+---------+---------+----------------+---------+-----------+------------+---------+---------+--------+----------------+------+-----------+-------+
# only showing top 20 rows

# %%
# TOTAL PLAYERS IN EACH FIFA BY GENDER

df.groupby('version', 'gender').count().orderBy('version', 'gender').show()
# Out:
# +-------+------+-----+
# |version|gender|count|
# +-------+------+-----+
# |     15|  male|16155|
# |     16|female|  248|
# |     16|  male|15623|
# |     17|female|  299|
# |     17|  male|17596|
# |     18|female|  317|
# |     18|  male|17954|
# |     19|female|  299|
# |     19|  male|18085|
# |     20|female|  345|
# |     20|  male|18483|
# |     21|female|  345|
# |     21|  male|18944|
# |     22|female|  391|
# |     22|  male|19239|
# +-------+------+-----+

# %%
# Display the players with overall score > 90 for each fifa

df.groupby('version', 'gender', 'overall').count().filter("overall > 90").show()
# Out:
# +-------+------+-------+-----+
# |version|gender|overall|count|
# +-------+------+-------+-----+
# |     18|  male|     91|    1|
# |     20|female|     93|    1|
# |     22|female|     92|    3|
# |     20|female|     92|    2|
# |     18|female|     91|    1|
# |     20|  male|     94|    1|
# |     22|  male|     92|    1|
# |     22|female|     91|    1|
# |     20|  male|     92|    1|
# |     20|female|     91|    3|
# |     18|female|     92|    1|
# |     20|  male|     93|    1|
# |     18|  male|     94|    1|
# |     22|  male|     91|    5|
# |     22|  male|     93|    1|
# |     18|  male|     93|    1|
# |     18|  male|     92|    3|
# |     20|  male|     91|    3|
# |     21|  male|     91|    4|
# |     21|  male|     93|    1|
# +-------+------+-------+-----+
# only showing top 20 rows

# %%
# Create temp views for queries
df.createOrReplaceTempView("fifa")

# %%
# Best 20 fifa players per year

# TUNE version

df_top_players_by_year = spark.sql("""

SELECT version, overall, short_name
FROM fifa 
WHERE version = 17
ORDER BY overall DESC
LIMIT 11;
 """).show()
# Out:
# +-------+-------+-----------------+
# |version|overall|       short_name|
# +-------+-------+-----------------+
# |     17|     94|Cristiano Ronaldo|
# |     17|     93|         L. Messi|
# |     17|     92|        L. Suárez|
# |     17|     92|         M. Neuer|
# |     17|     92|           Neymar|
# |     17|     92|         C. Lloyd|
# |     17|     91|       M. Rapinoe|
# |     17|     90|   R. Lewandowski|
# |     17|     90|           De Gea|
# |     17|     90|          G. Bale|
# |     17|     90|       J. Boateng|
# |     17|     90|   Z. Ibrahimović|
# |     17|     89|     Thiago Silva|
# |     17|     89|     Sergio Ramos|
# |     17|     89|            Marta|
# |     17|     89|        L. Modrić|
# |     17|     89|      C. Sinclair|
# |     17|     89|      T. Courtois|
# |     17|     89|        S. Agüero|
# |     17|     89|          M. Özil|
# +-------+-------+-----------------+
# only showing top 20 rows

# %%
# TOP PLAYER IN EACH FIFA

df_top_players = spark.sql("""

SELECT version, short_name, overall
FROM fifa WHERE (version,overall) IN
( SELECT version, MAX(overall)
  FROM fifa
  GROUP BY version
)
ORDER BY version

""")


df_top_players.show()
# Out:
# +-------+-----------------+-------+
# |version|       short_name|overall|
# +-------+-----------------+-------+
# |     15|         L. Messi|     93|
# |     16|         L. Messi|     94|
# |     17|Cristiano Ronaldo|     94|
# |     18|Cristiano Ronaldo|     94|
# |     19|Cristiano Ronaldo|     94|
# |     19|         L. Messi|     94|
# |     20|         L. Messi|     94|
# |     21|       M. Rapinoe|     93|
# |     21|         L. Messi|     93|
# |     22|         L. Messi|     93|
# +-------+-----------------+-------+

# %%
# Best potential fifa players per year

# TUNE version

df_top_players_by_year = spark.sql("""

SELECT version, potential, short_name
FROM fifa 
WHERE version = 17
ORDER BY potential DESC
 """).show()
# Out:
# +-------+---------+--------------------+
# |version|potential|          short_name|
# +-------+---------+--------------------+
# |     17|       95|              Neymar|
# |     17|       94|   Cristiano Ronaldo|
# |     17|       94|A. Stolsmo Hegerberg|
# |     17|       94|            P. Pogba|
# |     17|       93|         J. Johnston|
# |     17|       93|          V. Miedema|
# |     17|       93|            L. Messi|
# |     17|       93|    C. Graham Hansen|
# |     17|       93|         T. Courtois|
# |     17|       92|           L. Suárez|
# |     17|       92|              De Gea|
# |     17|       92|           P. Dybala|
# |     17|       92|            C. Lloyd|
# |     17|       92|        J. Rodríguez|
# |     17|       92|            M. Neuer|
# |     17|       92|        A. Griezmann|
# |     17|       91|         D. Marozsán|
# |     17|       91|          A. Kennedy|
# |     17|       91|            J. Oblak|
# |     17|       91|          M. Rapinoe|
# +-------+---------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank, col, row_number

# Transformation to get, for a specific fifa version and player gender, the sum of the top 11 players overall score for each team
df_fifa_n = df.where((col('version') == 17) & (col('gender') == 'male'))

n = 11
df_best11_per_team = df_fifa_n.select(col('*'), row_number().over(window).alias('club_num')) \
    .where(col('club_num') <= n)

df_best11_per_team = df_best11_per_team.groupBy('version', 'club_name').sum('overall').orderBy('sum(overall)', ascending=False).show(10)

# df_best5_per_teams.select(['club_name', 'league_name', 'short_name', 'overall', 'gender', 'version']).show(500)
# Out:
# +-------+-------------------+------------+
# |version|          club_name|sum(overall)|
# +-------+-------------------+------------+
# |     17|     Real Madrid CF|         967|
# |     17|  FC Bayern München|         965|
# |     17|       FC Barcelona|         964|
# |     17|           Juventus|         945|
# |     17|    Manchester City|         936|
# |     17|            Chelsea|         935|
# |     17|  Manchester United|         934|
# |     17|            Arsenal|         933|
# |     17|Paris Saint-Germain|         933|
# |     17| Atlético de Madrid|         930|
# +-------+-------------------+------------+
# only showing top 10 rows

# %%
# SQL equivalent of previous block

# Top teams wrt to 'overall' score of their best 11 players for each fifa version and player gender

# TUNE version and gender

df_top_teams_by_year_and_gender = spark.sql("""
SELECT club_name, SUM(overall) total
FROM (
    SELECT version, gender, club_name, overall, ROW_NUMBER() OVER(PARTITION BY club_name ORDER BY overall DESC) rn
    FROM fifa
    WHERE version = 20 and gender = 'male' and club_name <> 'unknown'
) x 
WHERE rn <= 11
GROUP BY club_name
ORDER BY total DESC

 """).show(100)
# Out:
# +--------------------+-----+
# |           club_name|total|
# +--------------------+-----+
# |        FC Barcelona|  968|
# |      Real Madrid CF|  963|
# |     Manchester City|  960|
# |            Juventus|  952|
# |           Liverpool|  945|
# | Paris Saint-Germain|  945|
# |   FC Bayern München|  944|
# |   Tottenham Hotspur|  940|
# |  Atlético de Madrid|  925|
# |   Borussia Dortmund|  925|
# |              Napoli|  924|
# |               Inter|  921|
# |             Arsenal|  917|
# |   Manchester United|  914|
# |             Chelsea|  911|
# |               Lazio|  905|
# |         Valencia CF|  903|
# | Bayer 04 Leverkusen|  900|
# | Real Betis Balompié|  898|
# |            AC Milan|  896|
# |                Ajax|  893|
# |          RB Leipzig|  892|
# |          Sevilla FC|  891|
# |            FC Porto|  890|
# |           AS Monaco|  889|
# |          SL Benfica|  888|
# |Athletic Club de ...|  886|
# |                Roma|  884|
# |             Everton|  883|
# |  Olympique Lyonnais|  882|
# |         Sporting CP|  881|
# |     West Ham United|  881|
# |       Villarreal CF|  880|
# |            Atalanta|  879|
# |      Leicester City|  877|
# |Wolverhampton Wan...|  877|
# |         Torino F.C.|  876|
# |           Getafe CF|  874|
# |       Real Sociedad|  873|
# |      TSG Hoffenheim|  873|
# |Borussia Möncheng...|  873|
# |Olympique de Mars...|  872|
# |       VfL Wolfsburg|  872|
# | Eintracht Frankfurt|  870|
# |            SD Eibar|  868|
# |             Watford|  868|
# |RCD Espanyol de B...|  866|
# |      Galatasaray SK|  864|
# |    SV Werder Bremen|  864|
# |        Boca Juniors|  864|
# |         Beşiktaş JK|  862|
# |      Crystal Palace|  861|
# |                 PSV|  860|
# |         River Plate|  860|
# |    RC Celta de Vigo|  859|
# |     AFC Bournemouth|  858|
# |         Racing Club|  857|
# |          Hertha BSC|  857|
# |    Newcastle United|  857|
# |       FC Schalke 04|  856|
# |Levante Unión Dep...|  855|
# | FC Lokomotiv Moscow|  855|
# |          LOSC Lille|  855|
# |             Burnley|  854|
# |    AS Saint-Étienne|  854|
# |Brighton & Hove A...|  851|
# |            Cagliari|  851|
# |    Shakhtar Donetsk|  850|
# |    Deportivo Alavés|  850|
# |            SC Braga|  849|
# |         Southampton|  849|
# |          Fiorentina|  849|
# |Montpellier Hérau...|  848|
# |          1. FC Köln|  847|
# |       Fenerbahçe SK|  847|
# |     Tigres U.A.N.L.|  846|
# |              Grêmio|  845|
# |  Real Valladolid CF|  844|
# |      U.C. Sampdoria|  844|
# |İstanbul Başakşeh...|  842|
# |      Club Brugge KV|  842|
# |Clube Atlético Mi...|  842|
# |               Genoa|  841|
# |      Olympiacos CFP|  841|
# |FC Girondins de B...|  841|
# |            OGC Nice|  840|
# |      Udinese Calcio|  840|
# |         FC Augsburg|  840|
# |         Aston Villa|  839|
# |Club Atlético Ind...|  839|
# |                PAOK|  838|
# |             Bologna|  837|
# |          CD Leganés|  837|
# |            KRC Genk|  836|
# |    Stade Rennais FC|  836|
# |        CF Monterrey|  836|
# |     1. FSV Mainz 05|  835|
# |       Internacional|  835|
# |      RSC Anderlecht|  834|
# |         Dynamo Kyiv|  833|
# +--------------------+-----+
# only showing top 100 rows

# %%
# Best potential teams based on the 'potential' score of their best 11 players for each fifa version and player gender

# TUNE version and gender

df_top_teams_by_year_and_gender = spark.sql("""
SELECT club_name, SUM(potential) total
FROM (
    SELECT version, gender, club_name, potential, ROW_NUMBER() OVER(PARTITION BY club_name ORDER BY potential DESC) rn
    FROM fifa
    WHERE version = 20 and gender = 'male' and club_name <> 'unknown'
) x 
WHERE rn <= 11
GROUP BY club_name
ORDER BY total DESC

 """).show(100)
# Out:
# +--------------------+-----+
# |           club_name|total|
# +--------------------+-----+
# |     Manchester City|  990|
# |        FC Barcelona|  990|
# |      Real Madrid CF|  984|
# |            Juventus|  975|
# |           Liverpool|  974|
# | Paris Saint-Germain|  972|
# |   Tottenham Hotspur|  970|
# |   FC Bayern München|  969|
# |  Atlético de Madrid|  965|
# |   Manchester United|  958|
# |   Borussia Dortmund|  956|
# |              Napoli|  956|
# |               Inter|  954|
# |             Chelsea|  954|
# |            AC Milan|  953|
# |             Arsenal|  950|
# |          RB Leipzig|  947|
# |  Olympique Lyonnais|  943|
# | Bayer 04 Leverkusen|  943|
# |         Valencia CF|  940|
# |                Roma|  939|
# |          SL Benfica|  939|
# |                Ajax|  936|
# |               Lazio|  935|
# |           AS Monaco|  935|
# |Wolverhampton Wan...|  930|
# |             Everton|  930|
# |          LOSC Lille|  929|
# |       Real Sociedad|  927|
# |            FC Porto|  926|
# |      Leicester City|  925|
# | Real Betis Balompié|  924|
# |          Hertha BSC|  924|
# |         Sporting CP|  922|
# |    RC Celta de Vigo|  921|
# |         River Plate|  920|
# |    Shakhtar Donetsk|  919|
# |Borussia Möncheng...|  919|
# |                 PSV|  919|
# |            Atalanta|  918|
# |          Sevilla FC|  917|
# |     AFC Bournemouth|  917|
# |RCD Espanyol de B...|  917|
# |     West Ham United|  916|
# |       FC Schalke 04|  916|
# |      Udinese Calcio|  915|
# |  Real Valladolid CF|  915|
# |        Boca Juniors|  912|
# |       VfL Wolfsburg|  912|
# |Athletic Club de ...|  912|
# |           Getafe CF|  911|
# |     Vélez Sarsfield|  910|
# | Eintracht Frankfurt|  910|
# |     PFC CSKA Moscow|  909|
# |    SV Werder Bremen|  907|
# |      U.C. Sampdoria|  906|
# |      RSC Anderlecht|  906|
# |            KRC Genk|  906|
# |         Torino F.C.|  905|
# |          Fiorentina|  904|
# |    Newcastle United|  904|
# |               Genoa|  903|
# |             Watford|  902|
# |      Spartak Moskva|  902|
# |Olympique de Mars...|  902|
# |         Southampton|  901|
# |      TSG Hoffenheim|  901|
# |       Villarreal CF|  901|
# |         Dynamo Kyiv|  901|
# |     1. FSV Mainz 05|  899|
# |U.S. Sassuolo Calcio|  899|
# |FC Girondins de B...|  898|
# |         Aston Villa|  898|
# |            SC Braga|  897|
# |      Club Brugge KV|  896|
# |    AS Saint-Étienne|  895|
# |        Norwich City|  895|
# |FC Red Bull Salzburg|  894|
# |            OGC Nice|  894|
# |             Bologna|  894|
# |          AZ Alkmaar|  892|
# |            Cagliari|  892|
# |         Racing Club|  892|
# |       Dinamo Zagreb|  891|
# |          1. FC Köln|  891|
# |           FC Nantes|  891|
# |       VfB Stuttgart|  890|
# |Levante Unión Dep...|  890|
# |Club Atlético Ind...|  889|
# |      Olympiacos CFP|  889|
# |         FC Augsburg|  887|
# |       FC Basel 1893|  887|
# |Brighton & Hove A...|  887|
# |RC Strasbourg Alsace|  886|
# |            SD Eibar|  886|
# |Montpellier Hérau...|  886|
# |          CD Leganés|  885|
# |    Deportivo Alavés|  885|
# | Club Atlético Lanús|  884|
# |        Leeds United|  884|
# +--------------------+-----+
# only showing top 100 rows

# %%
# SQL equivalent of previous block

# Show the sum of the best N player values year by year

# TUNE N

df_top_teams_by_year_and_gender = spark.sql("""
SELECT version, SUM(value_eur) total
FROM (
    SELECT version, value_eur, ROW_NUMBER() OVER(PARTITION BY version ORDER BY value_eur DESC) rn
    FROM fifa
) x 
WHERE rn <= 100
GROUP BY version
ORDER BY total DESC

 """).show()
# Out:
# +-------+----------+
# |version|     total|
# +-------+----------+
# |     21|7778500000|
# |     22|7717000000|
# |     19|5333000000|
# |     20|5220500000|
# |     18|4980000000|
# |     17|4318500000|
# |     16|3685000000|
# |     15|2630500000|
# +-------+----------+

# %%
spark.stop()
